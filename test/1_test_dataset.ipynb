# %%
import sys

sys.path.append("..")

# %%
from data.dataloader import LowLightDataModule
from utils.utils import show_batch

# %%
data_module = LowLightDataModule(
    train_dir="../data/1_train",
    valid_dir="../data/2_valid",
    bench_dir="../data/3_bench",
    infer_dir="../data/4_infer",
    image_size=256,
    batch_size=1,
    num_workers=4,
)

data_module.setup()

# %%
train_dataloader = data_module.train_dataloader()
val_dataloader = data_module.val_dataloader()
test_dataloader = data_module.test_dataloader()
predict_dataloader = data_module.predict_dataloader()

# %%
train_low, train_high = next(iter(train_dataloader))
print(train_low.shape)
print(train_high.shape)
show_batch(images=train_low)
show_batch(images=train_high)
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
val_low, val_high = next(iter(val_dataloader))
print(val_low.shape)
print(val_high.shape)
show_batch(images=val_low)
show_batch(images=val_high)
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
test_low, test_high = next(iter(test_dataloader[0]))
print(test_low.shape)
print(test_high.shape)
show_batch(images=test_low)
show_batch(images=test_high)
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
predict_low, predict_high = next(iter(predict_dataloader[0]))
print(predict_low.shape)
print(predict_high.shape)
show_batch(images=predict_low)
show_batch(images=predict_high)
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])
